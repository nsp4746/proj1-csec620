# %%
import pandas as pd
import numpy as np
import tensorflow as tf
file_path = 'Wednesday-workingHours.pcap_ISCX.csv'
data = pd.read_csv(file_path)

np.object = object

print(data.info())
print(data.head())
# Out:
# C:\Users\Nikhil\miniconda3\envs\tf-gpu\lib\site-packages\tensorflow\python\framework\dtypes.py:585: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   np.object,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import tensorflow as tf
#       4 file_path = 'Wednesday-workingHours.pcap_ISCX.csv'
#       5 data = pd.read_csv(file_path)
#
# File ~\miniconda3\envs\tf-gpu\lib\site-packages\tensorflow\__init__.py:41
#      38 import six as _six
#      39 import sys as _sys
# ---> 41 from tensorflow.python.tools import module_util as _module_util
#      42 from tensorflow.python.util.lazy_loader import LazyLoader as _LazyLoader
#      44 # Make sure code inside the TensorFlow codebase can use tf2.enabled() at import.
#
# ...
